# %%
import cv2
from datasets import load_dataset
import numpy as np
import tempfile
import IPython.display as ipd

dataset = load_dataset("fmagot01/videos")

video_data = dataset["train"][0]["video_data"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/franciscomagot/Documents/Sync/Code/avp2/avspeech_download/hf.ipynb Cell 1 line 1
#       <a href='vscode-notebook-cell:/Users/franciscomagot/Documents/Sync/Code/avp2/avspeech_download/hf.ipynb#W0sZmlsZQ%3D%3D?line=6'>7</a> dataset = load_dataset("fmagot01/videos")
#       <a href='vscode-notebook-cell:/Users/franciscomagot/Documents/Sync/Code/avp2/avspeech_download/hf.ipynb#W0sZmlsZQ%3D%3D?line=8'>9</a> video_data = dataset["train"][0]["video_data"]
# ---> <a href='vscode-notebook-cell:/Users/franciscomagot/Documents/Sync/Code/avp2/avspeech_download/hf.ipynb#W0sZmlsZQ%3D%3D?line=10'>11</a> Video(data=video_data, embed=True)
#
# NameError: name 'Video' is not defined

# %%
from IPython.display import Video

Video(video_data, embed=True, mimetype="video/mp4")
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
